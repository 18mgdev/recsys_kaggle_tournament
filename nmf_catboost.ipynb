# %% [markdown]
# # imports

# %%
# Celda 1: Carga de Librerías y Datos
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error

import catboost as cb

# %%
train_data = pd.read_csv("data/train.csv", sep=",")
test_data = pd.read_csv("data/test.csv", sep=",")

global_mean = train_data['rating'].mean()
print(f"Media global de ratings: {global_mean:.4f}")
# Out:
# Media global de ratings: 7.6047

# %%
train_data.head(5)
# Out:
#    user   item  rating
# 0     1  25715     7.0
# 1     1  25716    10.0
# 2     5  25851     9.0
# 3     6  25923     5.0
# 4     7  25924     6.0

# %%
test_data.head(5)
# Out:
#    ID   user   item
# 0   0   8117    268
# 1   1  10512  24393
# 2   2    534   1334
# 3   3  10984   6550
# 4   4   9093  22128

# %%
#train_data, val_split = train_test_split(train_data, test_size=0.2, random_state=42)

# %%
# Obtener listas únicas de usuarios e ítems del conjunto de entrenamiento
unique_users = train_data['user'].unique()
unique_items = train_data['item'].unique()

# Crear índices para usuarios e ítems
user_to_index = {user: idx for idx, user in enumerate(unique_users)}
item_to_index = {item: idx for idx, item in enumerate(unique_items)}

# Dimensiones de la matriz de ratings
num_users = len(unique_users)
num_items = len(unique_items)

print(f"Número de usuarios: {num_users}")
print(f"Número de ítems: {num_items}")
# Out:
# Número de usuarios: 73456
# Número de ítems: 171171

# %%
from scipy.sparse import csr_matrix

# Crear la matriz dispersa solo con el conjunto de entrenamiento
rows = train_data['user'].map(user_to_index).values
cols = train_data['item'].map(item_to_index).values
ratings = train_data['rating'].values

R_sparse = csr_matrix((ratings, (rows, cols)), shape=(num_users, num_items))

print(f"Matriz dispersa creada con dimensiones: {R_sparse.shape}")
print("Número de ratings no nulos en la matriz:", R_sparse.nnz)
# Out:
# Matriz dispersa creada con dimensiones: (73456, 171171)
# Número de ratings no nulos en la matriz: 390351

# %% [markdown]
# # nmf

# %%
# Celda 3: Inicialización de Parámetros y Factores Latentes con Bias
# Hiperparámetros
k = 20  # Número de factores latentes
lambda_ = 0.015  # Regularización
learning_rate = 0.003  # Tasa de aprendizaje
num_epochs = 60  # Número de iteraciones

# Media global de ratings
mu = global_mean

# Inicialización aleatoria de las matrices latentes U y V
U = np.random.normal(scale=1./k, size=(num_users, k))
V = np.random.normal(scale=1./k, size=(num_items, k))

# Inicialización de sesgos
bu = np.zeros(num_users)
bi = np.zeros(num_items)

print(f"Factores latentes inicializados: U ({U.shape}), V ({V.shape})")
print(f"Sesgos inicializados: bu ({bu.shape}), bi ({bi.shape})")
# Out:
# Factores latentes inicializados: U ((73456, 20)), V ((171171, 20))
# Sesgos inicializados: bu ((73456,)), bi ((171171,))

# %%
def train_nmf_with_bias(R_sparse, U, V, bu, bi, mu, lambda_, lr, num_epochs):
    rows, cols = R_sparse.nonzero()  # Índices de las posiciones no nulas en la matriz
    num_ratings = len(rows)

    for epoch in range(num_epochs):
        total_cost = 0
        for idx in range(num_ratings):
            i = rows[idx]  # Usuario
            j = cols[idx]  # Ítem
            r_ij = R_sparse[i, j]  # Rating real del usuario i sobre el ítem j

            # Predicción incluyendo el sesgo
            pred_ij = mu + bu[i] + bi[j] + np.dot(U[i, :], V[j, :])
            error = r_ij - pred_ij

            # Actualización de los factores latentes y sesgos
            bu[i] += lr * (error - lambda_ * bu[i])
            bi[j] += lr * (error - lambda_ * bi[j])
            U[i, :] += lr * (error * V[j, :] - lambda_ * U[i, :])
            V[j, :] += lr * (error * U[i, :] - lambda_ * V[j, :])

            # Costo regularizado
            total_cost += error**2 + (lambda_ / 2) * (np.linalg.norm(U[i, :])**2 + np.linalg.norm(V[j, :])**2 + bu[i]**2 + bi[j]**2)

        print(f"Época {epoch + 1}/{num_epochs} - Costo total: {total_cost:.4f}")

    return U, V, bu, bi

# %%
# Celda 5: Entrenamiento del Modelo NMF
print("Iniciando entrenamiento NMF...")
U, V, bu, bi = train_nmf_with_bias(R_sparse, U, V, bu, bi, mu, lambda_, learning_rate, num_epochs)
print("Entrenamiento completado.")
# Out:
# Iniciando entrenamiento NMF...
# Época 1/60 - Costo total: 1244721.9616
# Época 2/60 - Costo total: 1167359.6045
# Época 3/60 - Costo total: 1125079.1228
# Época 4/60 - Costo total: 1094260.3815
# Época 5/60 - Costo total: 1069459.4390
# Época 6/60 - Costo total: 1048400.3122
# Época 7/60 - Costo total: 1029879.3203
# Época 8/60 - Costo total: 1013154.8572
# Época 9/60 - Costo total: 997701.5720
# Época 10/60 - Costo total: 983091.8908
# Época 11/60 - Costo total: 968943.8066
# Época 12/60 - Costo total: 954937.6545
# Época 13/60 - Costo total: 940924.5068
# Época 14/60 - Costo total: 927074.4054
# Época 15/60 - Costo total: 913842.8955
# Época 16/60 - Costo total: 901615.9509
# Época 17/60 - Costo total: 890402.2016
# Época 18/60 - Costo total: 879940.2094
# Época 19/60 - Costo total: 869951.3420
# Época 20/60 - Costo total: 860238.9406
# Época 21/60 - Costo total: 850676.9110
# Época 22/60 - Costo total: 841183.4039
# Época 23/60 - Costo total: 831705.8556
# Época 24/60 - Costo total: 822214.7271
# Época 25/60 - Costo total: 812700.2504
# Época 26/60 - Costo total: 803168.3713
# Época 27/60 - Costo total: 793634.5027
# Época 28/60 - Costo total: 784116.0099
# Época 29/60 - Costo total: 774625.6215
# Época 30/60 - Costo total: 765167.6112
# Época 31/60 - Costo total: 755737.2356
# Época 32/60 - Costo total: 746322.7260
# Época 33/60 - Costo total: 736908.6705
# Época 34/60 - Costo total: 727479.6560
# Época 35/60 - Costo total: 718023.2857
# Época 36/60 - Costo total: 708532.0445
# Época 37/60 - Costo total: 699003.8947
# Época 38/60 - Costo total: 689441.8180
# Época 39/60 - Costo total: 679852.6874
# Época 40/60 - Costo total: 670245.8723
# Época 41/60 - Costo total: 660631.8976
# Época 42/60 - Costo total: 651021.3636
# Época 43/60 - Costo total: 641424.2239
# Época 44/60 - Costo total: 631849.4239
# Época 45/60 - Costo total: 622304.8425
# Época 46/60 - Costo total: 612797.4410
# Época 47/60 - Costo total: 603333.5143
# Época 48/60 - Costo total: 593918.9564
# Época 49/60 - Costo total: 584559.4746
# Época 50/60 - Costo total: 575260.7208
# Época 51/60 - Costo total: 566028.3362
# Época 52/60 - Costo total: 556867.9237
# Época 53/60 - Costo total: 547784.9733
# Época 54/60 - Costo total: 538784.7655
# Época 55/60 - Costo total: 529872.2766
# Época 56/60 - Costo total: 521052.0989
# Época 57/60 - Costo total: 512328.3865
# Época 58/60 - Costo total: 503704.8266
# Época 59/60 - Costo total: 495184.6355
# Época 60/60 - Costo total: 486770.5745
# Entrenamiento completado.

# %% [markdown]
# # catboost

# %%
def build_dataset_for_xgboost(R_sparse, U, V):
    rows, cols = R_sparse.nonzero()
    X = []
    y = []

    for i, j in zip(rows, cols):
        u_vec = U[i]  # vector latente del usuario
        v_vec = V[j]  # vector latente del ítem

        x_input = np.concatenate([u_vec, v_vec])  # entrada al modelo
        rating = R_sparse[i, j]

        X.append(x_input)
        y.append(rating)

    return np.array(X), np.array(y)

# %%
# Crear datos
X, y = build_dataset_for_xgboost(R_sparse, U, V)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Crear y entrenar el modelo
cb_model = cb.CatBoostRegressor(loss_function='RMSE', n_estimators=200)
print("Iniciando entrenamiento CatBoost...")
cb_model.fit(X_train, y_train)

# Evaluar
y_pred = cb_model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"RMSE en test: {rmse:.4f}")
# Out:
# Iniciando entrenamiento CatBoost...
# Learning rate set to 0.382527
# 0:	learn: 1.7912007	total: 167ms	remaining: 33.2s
# 1:	learn: 1.7399710	total: 192ms	remaining: 19s
# 2:	learn: 1.6927268	total: 219ms	remaining: 14.4s
# 3:	learn: 1.6517297	total: 244ms	remaining: 12s
# 4:	learn: 1.6327029	total: 268ms	remaining: 10.4s
# 5:	learn: 1.5944837	total: 295ms	remaining: 9.55s
# 6:	learn: 1.5584475	total: 321ms	remaining: 8.85s
# 7:	learn: 1.5414457	total: 346ms	remaining: 8.29s
# 8:	learn: 1.5097899	total: 372ms	remaining: 7.9s
# 9:	learn: 1.4815609	total: 400ms	remaining: 7.6s
# 10:	learn: 1.4595856	total: 424ms	remaining: 7.29s
# 11:	learn: 1.4358143	total: 449ms	remaining: 7.03s
# 12:	learn: 1.4244384	total: 474ms	remaining: 6.81s
# 13:	learn: 1.4040243	total: 497ms	remaining: 6.6s
# 14:	learn: 1.3930038	total: 521ms	remaining: 6.42s
# 15:	learn: 1.3740860	total: 546ms	remaining: 6.28s
# 16:	learn: 1.3625855	total: 569ms	remaining: 6.12s
# 17:	learn: 1.3446903	total: 596ms	remaining: 6.02s
# 18:	learn: 1.3280115	total: 622ms	remaining: 5.93s
# 19:	learn: 1.3122279	total: 648ms	remaining: 5.83s
# 20:	learn: 1.2968517	total: 673ms	remaining: 5.74s
# 21:	learn: 1.2892446	total: 697ms	remaining: 5.64s
# 22:	learn: 1.2814065	total: 720ms	remaining: 5.54s
# 23:	learn: 1.2758229	total: 743ms	remaining: 5.45s
# 24:	learn: 1.2631949	total: 769ms	remaining: 5.38s
# 25:	learn: 1.2592256	total: 792ms	remaining: 5.3s
# 26:	learn: 1.2571652	total: 813ms	remaining: 5.21s
# 27:	learn: 1.2459959	total: 838ms	remaining: 5.14s
# 28:	learn: 1.2357007	total: 865ms	remaining: 5.1s
# 29:	learn: 1.2312892	total: 892ms	remaining: 5.05s
# 30:	learn: 1.2275298	total: 920ms	remaining: 5.02s
# 31:	learn: 1.2203400	total: 945ms	remaining: 4.96s
# 32:	learn: 1.2166258	total: 967ms	remaining: 4.9s
# 33:	learn: 1.2141490	total: 993ms	remaining: 4.85s
# 34:	learn: 1.2104452	total: 1.03s	remaining: 4.84s
# 35:	learn: 1.2036635	total: 1.06s	remaining: 4.81s
# 36:	learn: 1.2005953	total: 1.08s	remaining: 4.77s
# 37:	learn: 1.1980608	total: 1.1s	remaining: 4.71s
# 38:	learn: 1.1924716	total: 1.13s	remaining: 4.67s
# 39:	learn: 1.1894704	total: 1.15s	remaining: 4.62s
# 40:	learn: 1.1852459	total: 1.18s	remaining: 4.57s
# 41:	learn: 1.1827899	total: 1.2s	remaining: 4.52s
# 42:	learn: 1.1801646	total: 1.23s	remaining: 4.47s
# 43:	learn: 1.1771023	total: 1.25s	remaining: 4.43s
# 44:	learn: 1.1757993	total: 1.27s	remaining: 4.38s
# 45:	learn: 1.1728251	total: 1.3s	remaining: 4.34s
# 46:	learn: 1.1706222	total: 1.32s	remaining: 4.3s
# 47:	learn: 1.1679898	total: 1.34s	remaining: 4.25s
# 48:	learn: 1.1656930	total: 1.37s	remaining: 4.21s
# 49:	learn: 1.1632228	total: 1.39s	remaining: 4.17s
# 50:	learn: 1.1598654	total: 1.42s	remaining: 4.14s
# 51:	learn: 1.1585102	total: 1.44s	remaining: 4.09s
# 52:	learn: 1.1570528	total: 1.46s	remaining: 4.05s
# 53:	learn: 1.1554434	total: 1.48s	remaining: 4.01s
# 54:	learn: 1.1537433	total: 1.51s	remaining: 3.98s
# 55:	learn: 1.1520097	total: 1.53s	remaining: 3.94s
# 56:	learn: 1.1497068	total: 1.56s	remaining: 3.9s
# 57:	learn: 1.1471541	total: 1.58s	remaining: 3.87s
# 58:	learn: 1.1447374	total: 1.6s	remaining: 3.83s
# 59:	learn: 1.1422813	total: 1.63s	remaining: 3.8s
# 60:	learn: 1.1414330	total: 1.65s	remaining: 3.76s
# 61:	learn: 1.1402150	total: 1.67s	remaining: 3.72s
# 62:	learn: 1.1376967	total: 1.7s	remaining: 3.69s
# 63:	learn: 1.1350714	total: 1.72s	remaining: 3.66s
# 64:	learn: 1.1334181	total: 1.75s	remaining: 3.63s
# 65:	learn: 1.1316556	total: 1.77s	remaining: 3.6s
# 66:	learn: 1.1298949	total: 1.79s	remaining: 3.56s
# 67:	learn: 1.1281827	total: 1.82s	remaining: 3.53s
# 68:	learn: 1.1263976	total: 1.84s	remaining: 3.5s
# 69:	learn: 1.1242802	total: 1.87s	remaining: 3.47s
# 70:	learn: 1.1224715	total: 1.89s	remaining: 3.44s
# 71:	learn: 1.1206662	total: 1.92s	remaining: 3.41s
# 72:	learn: 1.1187514	total: 1.95s	remaining: 3.38s
# 73:	learn: 1.1167178	total: 1.97s	remaining: 3.35s
# 74:	learn: 1.1150688	total: 1.99s	remaining: 3.32s
# 75:	learn: 1.1127076	total: 2.02s	remaining: 3.29s
# 76:	learn: 1.1116186	total: 2.04s	remaining: 3.27s
# 77:	learn: 1.1095185	total: 2.08s	remaining: 3.25s
# 78:	learn: 1.1078280	total: 2.1s	remaining: 3.22s
# 79:	learn: 1.1061716	total: 2.13s	remaining: 3.2s
# 80:	learn: 1.1047620	total: 2.16s	remaining: 3.18s
# 81:	learn: 1.1036063	total: 2.19s	remaining: 3.15s
# 82:	learn: 1.1027505	total: 2.21s	remaining: 3.12s
# 83:	learn: 1.1011547	total: 2.24s	remaining: 3.09s
# 84:	learn: 1.0998784	total: 2.26s	remaining: 3.06s
# 85:	learn: 1.0983532	total: 2.28s	remaining: 3.03s
# 86:	learn: 1.0968957	total: 2.31s	remaining: 3s
# 87:	learn: 1.0956414	total: 2.33s	remaining: 2.97s
# 88:	learn: 1.0946184	total: 2.36s	remaining: 2.94s
# 89:	learn: 1.0925619	total: 2.38s	remaining: 2.91s
# 90:	learn: 1.0910865	total: 2.41s	remaining: 2.88s
# 91:	learn: 1.0900063	total: 2.43s	remaining: 2.86s
# 92:	learn: 1.0890976	total: 2.46s	remaining: 2.83s
# 93:	learn: 1.0881732	total: 2.48s	remaining: 2.8s
# 94:	learn: 1.0874588	total: 2.5s	remaining: 2.77s
# 95:	learn: 1.0868300	total: 2.53s	remaining: 2.74s
# 96:	learn: 1.0855771	total: 2.55s	remaining: 2.71s
# 97:	learn: 1.0839973	total: 2.57s	remaining: 2.68s
# 98:	learn: 1.0833704	total: 2.63s	remaining: 2.68s
# 99:	learn: 1.0819910	total: 2.65s	remaining: 2.65s
# 100:	learn: 1.0809446	total: 2.68s	remaining: 2.63s
# 101:	learn: 1.0792630	total: 2.7s	remaining: 2.6s
# 102:	learn: 1.0781936	total: 2.73s	remaining: 2.57s
# 103:	learn: 1.0770108	total: 2.75s	remaining: 2.54s
# 104:	learn: 1.0760497	total: 2.77s	remaining: 2.51s
# 105:	learn: 1.0755018	total: 2.8s	remaining: 2.48s
# 106:	learn: 1.0740202	total: 2.82s	remaining: 2.45s
# 107:	learn: 1.0734655	total: 2.85s	remaining: 2.42s
# 108:	learn: 1.0720837	total: 2.87s	remaining: 2.4s
# 109:	learn: 1.0714064	total: 2.9s	remaining: 2.37s
# 110:	learn: 1.0703779	total: 2.92s	remaining: 2.34s
# 111:	learn: 1.0696048	total: 2.94s	remaining: 2.31s
# 112:	learn: 1.0690897	total: 2.96s	remaining: 2.28s
# 113:	learn: 1.0685582	total: 2.98s	remaining: 2.25s
# 114:	learn: 1.0680178	total: 3.01s	remaining: 2.22s
# 115:	learn: 1.0668508	total: 3.03s	remaining: 2.2s
# 116:	learn: 1.0661212	total: 3.06s	remaining: 2.17s
# 117:	learn: 1.0652855	total: 3.08s	remaining: 2.14s
# 118:	learn: 1.0646292	total: 3.1s	remaining: 2.11s
# 119:	learn: 1.0634325	total: 3.13s	remaining: 2.08s
# 120:	learn: 1.0621004	total: 3.15s	remaining: 2.06s
# 121:	learn: 1.0615758	total: 3.17s	remaining: 2.03s
# 122:	learn: 1.0604859	total: 3.19s	remaining: 2s
# 123:	learn: 1.0593077	total: 3.22s	remaining: 1.97s
# 124:	learn: 1.0585968	total: 3.24s	remaining: 1.95s
# 125:	learn: 1.0577483	total: 3.27s	remaining: 1.92s
# 126:	learn: 1.0564010	total: 3.29s	remaining: 1.89s
# 127:	learn: 1.0553965	total: 3.31s	remaining: 1.86s
# 128:	learn: 1.0548085	total: 3.34s	remaining: 1.84s
# 129:	learn: 1.0540137	total: 3.36s	remaining: 1.81s
# 130:	learn: 1.0532311	total: 3.38s	remaining: 1.78s
# 131:	learn: 1.0526808	total: 3.41s	remaining: 1.75s
# 132:	learn: 1.0517729	total: 3.43s	remaining: 1.73s
# 133:	learn: 1.0507011	total: 3.46s	remaining: 1.7s
# 134:	learn: 1.0496668	total: 3.48s	remaining: 1.68s
# 135:	learn: 1.0488279	total: 3.51s	remaining: 1.65s
# 136:	learn: 1.0479531	total: 3.54s	remaining: 1.63s
# 137:	learn: 1.0468788	total: 3.57s	remaining: 1.6s
# 138:	learn: 1.0456573	total: 3.59s	remaining: 1.58s
# 139:	learn: 1.0446249	total: 3.62s	remaining: 1.55s
# 140:	learn: 1.0434233	total: 3.65s	remaining: 1.52s
# 141:	learn: 1.0425596	total: 3.67s	remaining: 1.5s
# 142:	learn: 1.0415925	total: 3.7s	remaining: 1.47s
# 143:	learn: 1.0410150	total: 3.72s	remaining: 1.45s
# 144:	learn: 1.0400431	total: 3.74s	remaining: 1.42s
# 145:	learn: 1.0393855	total: 3.77s	remaining: 1.39s
# 146:	learn: 1.0386624	total: 3.79s	remaining: 1.37s
# 147:	learn: 1.0381207	total: 3.81s	remaining: 1.34s
# 148:	learn: 1.0374844	total: 3.84s	remaining: 1.31s
# 149:	learn: 1.0367242	total: 3.86s	remaining: 1.29s
# 150:	learn: 1.0359769	total: 3.89s	remaining: 1.26s
# 151:	learn: 1.0354014	total: 3.91s	remaining: 1.24s
# 152:	learn: 1.0344538	total: 3.94s	remaining: 1.21s
# 153:	learn: 1.0339931	total: 3.96s	remaining: 1.18s
# 154:	learn: 1.0332938	total: 3.98s	remaining: 1.16s
# 155:	learn: 1.0324482	total: 4.01s	remaining: 1.13s
# 156:	learn: 1.0320104	total: 4.03s	remaining: 1.1s
# 157:	learn: 1.0312460	total: 4.06s	remaining: 1.08s
# 158:	learn: 1.0305699	total: 4.08s	remaining: 1.05s
# 159:	learn: 1.0297003	total: 4.11s	remaining: 1.03s
# 160:	learn: 1.0286325	total: 4.13s	remaining: 1s
# 161:	learn: 1.0277461	total: 4.16s	remaining: 976ms
# 162:	learn: 1.0272150	total: 4.19s	remaining: 951ms
# 163:	learn: 1.0266411	total: 4.22s	remaining: 926ms
# 164:	learn: 1.0258055	total: 4.24s	remaining: 900ms
# 165:	learn: 1.0249622	total: 4.27s	remaining: 875ms
# 166:	learn: 1.0237848	total: 4.3s	remaining: 850ms
# 167:	learn: 1.0234334	total: 4.33s	remaining: 824ms
# 168:	learn: 1.0230196	total: 4.35s	remaining: 798ms
# 169:	learn: 1.0223625	total: 4.38s	remaining: 773ms
# 170:	learn: 1.0214033	total: 4.4s	remaining: 747ms
# 171:	learn: 1.0204268	total: 4.43s	remaining: 721ms
# 172:	learn: 1.0196267	total: 4.46s	remaining: 695ms
# 173:	learn: 1.0192452	total: 4.48s	remaining: 669ms
# 174:	learn: 1.0185481	total: 4.51s	remaining: 644ms
# 175:	learn: 1.0181165	total: 4.53s	remaining: 618ms
# 176:	learn: 1.0177139	total: 4.55s	remaining: 592ms
# 177:	learn: 1.0169947	total: 4.58s	remaining: 566ms
# 178:	learn: 1.0161321	total: 4.6s	remaining: 540ms
# 179:	learn: 1.0156073	total: 4.62s	remaining: 514ms
# 180:	learn: 1.0150361	total: 4.65s	remaining: 488ms
# 181:	learn: 1.0144502	total: 4.67s	remaining: 462ms
# 182:	learn: 1.0138969	total: 4.7s	remaining: 437ms
# 183:	learn: 1.0133329	total: 4.72s	remaining: 411ms
# 184:	learn: 1.0127577	total: 4.75s	remaining: 385ms
# 185:	learn: 1.0124497	total: 4.77s	remaining: 359ms
# 186:	learn: 1.0119237	total: 4.79s	remaining: 333ms
# 187:	learn: 1.0113793	total: 4.81s	remaining: 307ms
# 188:	learn: 1.0107747	total: 4.84s	remaining: 282ms
# 189:	learn: 1.0102060	total: 4.86s	remaining: 256ms
# 190:	learn: 1.0094482	total: 4.89s	remaining: 230ms
# 191:	learn: 1.0089048	total: 4.91s	remaining: 205ms
# 192:	learn: 1.0078190	total: 4.94s	remaining: 179ms
# 193:	learn: 1.0070139	total: 4.96s	remaining: 153ms
# 194:	learn: 1.0063502	total: 4.99s	remaining: 128ms
# 195:	learn: 1.0058347	total: 5.01s	remaining: 102ms
# 196:	learn: 1.0051063	total: 5.04s	remaining: 76.7ms
# 197:	learn: 1.0044747	total: 5.06s	remaining: 51.1ms
# 198:	learn: 1.0040080	total: 5.08s	remaining: 25.5ms
# 199:	learn: 1.0032894	total: 5.11s	remaining: 0us
# RMSE en test: 1.0201

# %%
def predict_rating(uid, iid, U, V, cb_model, user_to_index, item_to_index, mu):
    # Verifica si el usuario y el ítem existen en los índices
    if uid in user_to_index and iid in item_to_index:
        user_idx = user_to_index[uid]
        item_idx = item_to_index[iid]

        # Construimos el vector de entrada para XGBoost
        u_vec = U[user_idx]
        v_vec = V[item_idx]
        x_input = np.concatenate([u_vec, v_vec]).reshape(1, -1)

        # Predicción con XGBoost
        pred = cb_model.predict(x_input)[0]
    else:
        # Si no se puede predecir, devolver la media global
        pred = mu

    # Clamping entre 1 y 10 con formato decimal ".0"
    return f"{round(max(1, min(10, pred)))}.0"

# %% [markdown]
# # generacion csv

# %%
# Celda 10: Generación del Archivo de Predicciones
print("Generando predicciones finales...")
predictions = []

for _, row in test_data.iterrows():
    uid, iid, row_id = row['user'], row['item'], row['ID']
    pred_rating = predict_rating(uid=uid, iid=iid, 
                   U=U, V=V, 
                   cb_model=cb_model, 
                   user_to_index=user_to_index, 
                   item_to_index=item_to_index, 
                   mu=mu)

    predictions.append((row_id, pred_rating))

# Crear el DataFrame con las predicciones
predictions_df = pd.DataFrame(predictions, columns=["ID", "rating"])

# Guardar las predicciones en formato CSV
output_filename = "predictions_pmf_catboost.csv"
predictions_df.to_csv(output_filename, index=False)
print(f"Archivo '{output_filename}' generado correctamente.")
# Out:
# Generando predicciones finales...
# Archivo 'predictions_pmf_catboost.csv' generado correctamente.
